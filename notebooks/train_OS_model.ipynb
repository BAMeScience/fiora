# %%
import sys
import torch

seed = 42
#torch.set_default_dtype(torch.float64)
torch.manual_seed(seed)
torch.set_printoptions(precision=2, sci_mode=False)


import pandas as pd
import numpy as np
import ast
import copy

# Load Modules
sys.path.append("..")
from os.path import expanduser
home = expanduser("~")
from fiora.MOL.constants import DEFAULT_PPM, PPM, DEFAULT_MODES
from fiora.IO.LibraryLoader import LibraryLoader
from fiora.MOL.FragmentationTree import FragmentationTree 
import fiora.visualization.spectrum_visualizer as sv

from sklearn.metrics import r2_score
import scipy
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

print(f'Working with Python {sys.version}')
# Out:
# [06:58:49] WARNING: not removing hydrogen atom without neighbors
# [06:58:49] WARNING: not removing hydrogen atom without neighbors
# [06:58:49] WARNING: not removing hydrogen atom without neighbors
# Working with Python 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]

# %% [markdown]
# ## Data

# %%
from typing import Literal
lib: Literal["NIST", "MSDIAL", "NIST/MSDIAL"] = "MSDIAL"
print(f"Preparing {lib} library")

test_run = False # Default: False
if test_run:
    print("+++ This is a test run with a small subset of data points. Results are not representative. +++")
# Out:
# Preparing MSDIAL library

# %%
# key map to read metadata from pandas DataFrame
metadata_key_map = {
                "name": "Name",
                "collision_energy":  "CE", 
                "instrument": "Instrument_type",
                "ionization": "Ionization",
                "precursor_mz": "PrecursorMZ",
                "precursor_mode": "Precursor_type",
                "retention_time": "RETENTIONTIME",
                "ccs": "CCS"
                }


#
# Load specified libraries and align metadata
#

def load_training_data():
    L = LibraryLoader()
    df = L.load_from_csv(f"{home}/data/metabolites/preprocessed/datasplits_Jan24.csv")
    df = df[df["lib"] == lib]
    return df

df = load_training_data()

# Restore dictionary values
dict_columns = ["peaks", "summary"]
for col in dict_columns:
    df[col] = df[col].apply(lambda x: ast.literal_eval(x.replace('nan', 'None')))
    #df[col] = df[col].apply(ast.literal_eval)
    
df['group_id'] = df['group_id'].astype(int)

# %%
# import polars as pl
# pdf = pl.from_pandas(df)

# %%
# %%capture
from fiora.MOL.Metabolite import Metabolite
from fiora.GNN.AtomFeatureEncoder import AtomFeatureEncoder
from fiora.GNN.BondFeatureEncoder import BondFeatureEncoder
from fiora.GNN.SetupFeatureEncoder import SetupFeatureEncoder


CE_upper_limit = 100.0
weight_upper_limit = 1000.0


if test_run:
    df = df.iloc[:10000,:]
    #df = df.iloc[5000:20000,:]


df["Metabolite"] = df["SMILES"].apply(Metabolite)
df["Metabolite"].apply(lambda x: x.create_molecular_structure_graph())

node_encoder = AtomFeatureEncoder(feature_list=["symbol", "num_hydrogen", "ring_type"])
bond_encoder = BondFeatureEncoder(feature_list=["bond_type", "ring_type"])
setup_encoder = SetupFeatureEncoder(feature_list=["collision_energy", "molecular_weight", "precursor_mode", "instrument"])
rt_encoder = SetupFeatureEncoder(feature_list=["molecular_weight", "precursor_mode", "instrument"])

setup_encoder.normalize_features["collision_energy"]["max"] = CE_upper_limit 
setup_encoder.normalize_features["molecular_weight"]["max"] = weight_upper_limit 
rt_encoder.normalize_features["molecular_weight"]["max"] = weight_upper_limit 

df["Metabolite"].apply(lambda x: x.compute_graph_attributes(node_encoder, bond_encoder))
df.apply(lambda x: x["Metabolite"].set_id(x["group_id"]) , axis=1)

#df["summary"] = df.apply(lambda x: {key: x[name] for key, name in metadata_key_map.items()}, axis=1)
df.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder, rt_encoder), axis=1)
df.apply(lambda x: x["Metabolite"].set_loss_weight(x["loss_weight"]), axis=1)

# %%
# %%capture
df["Metabolite"].apply(lambda x: x.fragment_MOL(depth=1))
df.apply(lambda x: x["Metabolite"].match_fragments_to_peaks(x["peaks"]["mz"], x["peaks"]["intensity"], tolerance=x["ppm_peak_tolerance"]), axis=1)

# %%
df["num_peak_matches"] = df["Metabolite"].apply(lambda x: x.match_stats["num_peak_matches"])
print(sum(df["num_peak_matches"] < 1))
df = df[df["num_peak_matches"] >= 2]
# Out:
# 0

# %% [markdown]
# ##### Load Casmi data

# %%
casmi16_path = f"{home}/data/metabolites/CASMI_2016/casmi16_withCCS.csv"
casmi22_path = f"{home}/data/metabolites/CASMI_2022/casmi22_withCCS.csv"

df_cas = pd.read_csv(casmi16_path, index_col=[0], low_memory=False)
df_cas22 = pd.read_csv(casmi22_path, index_col=[0], low_memory=False)

# Restore dictionary values
dict_columns = ["peaks", "Candidates"]
for col in dict_columns:
    df_cas[col] = df_cas[col].apply(ast.literal_eval)

df_cas22["peaks"] = df_cas22["peaks"].apply(ast.literal_eval)

# %%
# %%capture
from fiora.MOL.collision_energy import NCE_to_eV

df_cas["RETENTIONTIME"] = df_cas["RTINSECONDS"] / 60.0
df_cas["Metabolite"] = df_cas["SMILES"].apply(Metabolite)
df_cas["Metabolite"].apply(lambda x: x.create_molecular_structure_graph())

df_cas["Metabolite"].apply(lambda x: x.compute_graph_attributes(node_encoder, bond_encoder))
df_cas["CE"] = 20.0 # actually stepped 20/35/50
df_cas["Instrument_type"] = "HCD" # CHECK if correct Orbitrap

metadata_key_map16 = {"collision_energy":  "CE", 
                 "instrument": "Instrument_type",
                 "precursor_mz": "PRECURSOR_MZ",
                 'precursor_mode': "Precursor_type",
                 "retention_time": "RETENTIONTIME"
                 }

df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
df_cas.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder), axis=1)

# Fragmentation
df_cas["Metabolite"].apply(lambda x: x.fragment_MOL(depth=1))
df_cas.apply(lambda x: x["Metabolite"].match_fragments_to_peaks(x["peaks"]["mz"], x["peaks"]["intensity"], tolerance=100 * PPM), axis=1) # Optional: use mz_cut instead

#
# CASMI 22
#

df_cas22["Metabolite"] = df_cas22["SMILES"].apply(Metabolite)
df_cas22["Metabolite"].apply(lambda x: x.create_molecular_structure_graph())

df_cas22["Metabolite"].apply(lambda x: x.compute_graph_attributes(node_encoder, bond_encoder))
df_cas22["CE"] = df_cas22.apply(lambda x: NCE_to_eV(x["NCE"], x["precursor_mz"]), axis=1)

metadata_key_map22 = {"collision_energy":  "CE", 
                 "instrument": "Instrument_type",
                 "precursor_mz": "precursor_mz",
                 'precursor_mode': "Precursor_type",
                 "retention_time": "ChallengeRT"
                 }

df_cas22["summary"] = df_cas22.apply(lambda x: {key: x[name] for key, name in metadata_key_map22.items()}, axis=1)
df_cas22.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder, rt_encoder), axis=1)

# Fragmentation
df_cas22["Metabolite"].apply(lambda x: x.fragment_MOL(depth=1))
df_cas22.apply(lambda x: x["Metabolite"].match_fragments_to_peaks(x["peaks"]["mz"], x["peaks"]["intensity"], tolerance=100 * PPM), axis=1) # Optional: use mz_cut instead

df_cas22 = df_cas22.reset_index()

# %% [markdown]
# ## Model Training and Testing

# %%
from fiora.GNN.Trainer import Trainer
import torch_geometric as geom

if torch.cuda.is_available(): 
    torch.cuda.empty_cache()
    dev = "cuda:1"
else: 
    dev = "cpu" 
 
print(f"Running on device: {dev}")
# Out:
# Running on device: cuda:1

# %% [markdown]
# ##### Load Data

# %%
print(df.groupby("dataset")["group_id"].unique().apply(len))

df_test = df[df["dataset"] == "test"]
df_train = df[df["dataset"].isin(["training", "validation"])]
# Out:
# dataset
# test           445
# training      3514
# validation     449
# Name: group_id, dtype: int64

# %%
geo_data = df_train["Metabolite"].apply(lambda x: x.as_geometric_data().to(dev)).values
print(f"Prepared training/validation with {len(geo_data)} data points")
# Out:
# Prepared training/validation with 17669 data points

# %% [markdown]
# ##### Prepare Model

# %%
model_params = {
    'param_tag': 'default',
    'gnn_type': 'RGCNConv',
    'depth': 6,
    'hidden_dimension': 300,
    'dense_layers': 2,
    'embedding_aggregation': 'concat',
    'embedding_dimension': 300,
    'input_dropout': 0.2, 
    'latent_dropout': 0.1,
    'node_feature_layout': node_encoder.feature_numbers,
    'edge_feature_layout': bond_encoder.feature_numbers,    
    'static_feature_dimension': geo_data[0]["static_edge_features"].shape[1],
    'static_rt_feature_dimension': geo_data[0]["static_rt_features"].shape[1],
    'output_dimension': len(DEFAULT_MODES) * 2, # per edge 
    
    # Keep track of encoded features
    'atom_features': node_encoder.feature_list,
    'atom_features': bond_encoder.feature_list, 
    'setup_features': setup_encoder.feature_list,
    'rt_features': rt_encoder.feature_list,
    
}
training_params = {
    'epochs': 200 if not test_run else 10, 
    'batch_size': 256, 
    #'train_val_split': 0.90,
    'learning_rate': 0.0004, 
    'with_RT': False, 
    'with_CCS': False
}

# %% [markdown]
# ##### Begin Training

# %%
from fiora.GNN.GNNModules import GNNCompiler
from fiora.GNN.Losses import WeightedMSELoss, WeightedMSEMetric
from fiora.MS.SimulationFramework import SimulationFramework

fiora = SimulationFramework(None, dev=dev, with_RT=True, with_CCS=True)
# fiora = SimulationFramework(None, dev=dev, with_RT=training_params["with_RT"], with_CCS=training_params["with_CCS"])
np.seterr(invalid='ignore')
tag = "training"
val_interval = 1
metric_dict= {"mse": WeightedMSEMetric}
loss_fn = WeightedMSELoss()
all_together = False

if all_together:
    val_interval = 200
    metric_dict=None
    loss_fn = torch.nn.MSELoss()

def train_new_model():
    model = GNNCompiler(model_params).to(dev)
        
    y_label = 'compiled_probsALL'
    optimizer = torch.optim.Adam(model.parameters(), lr=training_params["learning_rate"])
    if all_together:
        trainer = Trainer(geo_data, y_tag=y_label, problem_type="regression", only_training=True, metric_dict=metric_dict, split_by_group=True, seed=seed, device=dev)
        scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98)
    else:
        train_keys, val_keys = df[df["dataset"] == "training"]["group_id"].unique(), df[df["dataset"] == "validation"]["group_id"].unique()
        trainer = Trainer(geo_data, y_tag=y_label, problem_type="regression", train_keys=train_keys, val_keys=val_keys, metric_dict=metric_dict, split_by_group=True, seed=seed, device=dev)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience = 8, factor=0.5, mode = 'min', verbose = True)

    
    checkpoints = trainer.train(model, optimizer, loss_fn, scheduler=scheduler, batch_size=training_params['batch_size'], epochs=training_params["epochs"], val_every_n_epochs=1, with_CCS=training_params["with_CCS"], with_RT=training_params["with_RT"], masked_validation=False, tag=tag) #, mask_name="compiled_validation_maskALL")   
    
    return model, checkpoints

def simulate_all(model, DF):
    return fiora.simulate_all(DF, model)

    
def test_model(model, DF, return_df=False):
    dft = simulate_all(model, DF)
    
    if return_df:
        return dft
    return dft["spectral_sqrt_cosine"].values

# %% [markdown]
# ##### Test CASMI 16 and 22

# %%
from fiora.MOL.collision_energy import NCE_to_eV
from fiora.MS.spectral_scores import spectral_cosine, spectral_reflection_cosine, reweighted_dot
from fiora.MS.ms_utility import merge_annotated_spectrum

def test_cas16(model, df_cas=df_cas, return_df=False):
    
    df_cas["NCE"] = 20.0 # actually stepped NCE 20/35/50
    df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
    df_cas["step1_CE"] = df_cas["CE"]
    df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
    df_cas.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder, rt_encoder), axis=1)
    df_cas = fiora.simulate_all(df_cas, model, suffix="_20")

    df_cas["NCE"] = 35.0 # actually stepped NCE 20/35/50
    df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
    df_cas["step2_CE"] = df_cas["CE"]
    df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
    df_cas.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder, rt_encoder), axis=1)
    df_cas = fiora.simulate_all(df_cas, model, suffix="_35")


    df_cas["NCE"] = 50.0 # actually stepped NCE 20/35/50
    df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
    df_cas["step3_CE"] = df_cas["CE"]
    df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
    df_cas.apply(lambda x: x["Metabolite"].add_metadata(x["summary"], setup_encoder, rt_encoder), axis=1)
    df_cas = fiora.simulate_all(df_cas, model, suffix="_50")

    df_cas["avg_CE"] = (df_cas["step1_CE"] + df_cas["step2_CE"] + df_cas["step3_CE"]) / 3

    df_cas["merged_peaks"] = df_cas.apply(lambda x: merge_annotated_spectrum(merge_annotated_spectrum(x["sim_peaks_20"], x["sim_peaks_35"]), x["sim_peaks_50"]) , axis=1)
    df_cas["merged_cosine"] = df_cas.apply(lambda x: spectral_cosine(x["peaks"], x["merged_peaks"]), axis=1)
    df_cas["merged_sqrt_cosine"] = df_cas.apply(lambda x: spectral_cosine(x["peaks"], x["merged_peaks"], transform=np.sqrt), axis=1)
    df_cas["merged_refl_cosine"] = df_cas.apply(lambda x: spectral_reflection_cosine(x["peaks"], x["merged_peaks"], transform=np.sqrt), axis=1)
    df_cas["merged_steins"] = df_cas.apply(lambda x: reweighted_dot(x["peaks"], x["merged_peaks"]), axis=1)
    df_cas["spectral_sqrt_cosine"] = df_cas["merged_sqrt_cosine"] # just remember it is merged

    df_cas["coverage"] = df_cas["Metabolite"].apply(lambda x: x.match_stats["coverage"])
    df_cas["RT_pred"] = df_cas["RT_pred_35"]
    df_cas["RT_dif"] = df_cas["RT_dif_35"]
    df_cas["CCS_pred"] = df_cas["CCS_pred_35"]
    df_cas["library"] = "CASMI-16"
    
    if return_df:
        return df_cas
    
    return df_cas["merged_sqrt_cosine"].values

# %%
raise KeyboardInterrupt("Stop before starting a new training run!")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 raise KeyboardInterrupt("Stop before starting a new training run!")
#
# KeyboardInterrupt: Stop before starting a new training run!

# %%
results = []
print(f"Training model")
model, checkpoints = train_new_model()
# Out:
# Training model
# Using pre-arranged train/validation set
# 	Validation RMSE: 0.010710
# 	Validation RMSE: 0.010306
# 	Validation RMSE: 0.010103
# 	Validation RMSE: 0.009902
# 	Validation RMSE: 0.009700
# 	Validation RMSE: 0.009899
# 	Validation RMSE: 0.009997
# 	Validation RMSE: 0.009996
# 	Validation RMSE: 0.009794
# 	Validation RMSE: 0.0094094
# 	Validation RMSE: 0.0095092
# 	Validation RMSE: 0.0094091
# 	Validation RMSE: 0.0091090
# 	Validation RMSE: 0.0092087
# 	Validation RMSE: 0.0092087
# 	Validation RMSE: 0.0092085
# 	Validation RMSE: 0.0091084
# 	Validation RMSE: 0.0091083
# 	Validation RMSE: 0.0090083
# 	Validation RMSE: 0.0091082
# 	Validation RMSE: 0.0092080
# 	Validation RMSE: 0.0090080
# 	Validation RMSE: 0.0091080
# 	Validation RMSE: 0.0090079
# 	Validation RMSE: 0.0089077
# 	Validation RMSE: 0.0089077
# 	Validation RMSE: 0.0089075
# 	Validation RMSE: 0.0088076
# 	Validation RMSE: 0.0090075
# 	Validation RMSE: 0.0089074
# 	Validation RMSE: 0.0088073
# 	Validation RMSE: 0.0088073
# 	Validation RMSE: 0.0088073
# 	Validation RMSE: 0.0087072
# 	Validation RMSE: 0.0091071
# 	Validation RMSE: 0.0088071
# 	Validation RMSE: 0.0087072
# 	Validation RMSE: 0.0089070
# 	Validation RMSE: 0.0090069
# 	Validation RMSE: 0.0088068
# 	Validation RMSE: 0.0089069
# 	Validation RMSE: 0.0086069
# 	Validation RMSE: 0.0087068
# 	Validation RMSE: 0.0088067
# 	Validation RMSE: 0.0088067
# 	Validation RMSE: 0.0088067
# 	Validation RMSE: 0.0087066
# 	Validation RMSE: 0.0087066
# 	Validation RMSE: 0.0088066
# 	Validation RMSE: 0.0090066
# 	Validation RMSE: 0.0089065
# Epoch 00051: reducing learning rate of group 0 to 2.0000e-04.
# 	Validation RMSE: 0.0088062
# 	Validation RMSE: 0.0087060
# 	Validation RMSE: 0.0087059
# 	Validation RMSE: 0.0088059
# 	Validation RMSE: 0.0087060
# 	Validation RMSE: 0.0088059
# 	Validation RMSE: 0.0086058
# 	Validation RMSE: 0.0087058
# 	Validation RMSE: 0.0088058
# Epoch 00060: reducing learning rate of group 0 to 1.0000e-04.
# 	Validation RMSE: 0.0087056
# 	Validation RMSE: 0.0087056
# 	Validation RMSE: 0.0087055
# 	Validation RMSE: 0.0087055
# 	Validation RMSE: 0.0087055
# 	Validation RMSE: 0.0087054
# 	Validation RMSE: 0.0087055
# 	Validation RMSE: 0.0088054
# 	Validation RMSE: 0.0088054
# Epoch 00069: reducing learning rate of group 0 to 5.0000e-05.
# 	Validation RMSE: 0.0087053
# 	Validation RMSE: 0.0087053
# 	Validation RMSE: 0.0088053
# 	Validation RMSE: 0.0087053
# 	Validation RMSE: 0.0088053
# 	Validation RMSE: 0.0088053
# 	Validation RMSE: 0.0087053
# 	Validation RMSE: 0.0087053
# 	Validation RMSE: 0.0087052
# Epoch 00078: reducing learning rate of group 0 to 2.5000e-05.
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0087052
# 	Validation RMSE: 0.0087052
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0087052
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0087051
# Epoch 00087: reducing learning rate of group 0 to 1.2500e-05.
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088052
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# Epoch 00096: reducing learning rate of group 0 to 6.2500e-06.
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.0088051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00105: reducing learning rate of group 0 to 3.1250e-06.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00114: reducing learning rate of group 0 to 1.5625e-06.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00123: reducing learning rate of group 0 to 7.8125e-07.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00132: reducing learning rate of group 0 to 3.9063e-07.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00141: reducing learning rate of group 0 to 1.9531e-07.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00150: reducing learning rate of group 0 to 9.7656e-08.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00159: reducing learning rate of group 0 to 4.8828e-08.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00168: reducing learning rate of group 0 to 2.4414e-08.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# Epoch 00177: reducing learning rate of group 0 to 1.2207e-08.
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880051
# 	Validation RMSE: 0.00880050
# 	Validation RMSE: 0.00880050
# Finished Training!

# %%
checkpoints
# Out:
# {'epoch': 42,
#  'val_loss': 7.356654532486573e-05,
#  'file': '../../checkpoint_training.best.pt'}

# %%
model = GNNCompiler.load(checkpoints["file"])
val_results = test_model(model, df_train[df_train["dataset"]== "validation"])
test_results = test_model(model, df_test)
casmi16_results = test_cas16(model)
casmi16_p = test_cas16(model, df_cas[df_cas["Precursor_type"] == "[M+H]+"])
casmi16_n = test_cas16(model, df_cas[df_cas["Precursor_type"] == "[M-H]-"])
casmi22_results = test_model(model, df_cas22)
casmi22_p = test_model(model, df_cas22[df_cas22["Precursor_type"] == "[M+H]+"])
casmi22_n = test_model(model, df_cas22[df_cas22["Precursor_type"] == "[M-H]-"])
    
results.append({"model": model, "validation": val_results, "test": test_results, "casmi16": casmi16_results, "casmi22": casmi22_results, "casmi16+": casmi16_p, "casmi16-": casmi16_n, "casmi22+": casmi22_p, "casmi22-": casmi22_n})
# Out:
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /tmp/ipykernel_1354074/3992563308.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["NCE"] = 20.0 # actually stepped NCE 20/35/50
# /tmp/ipykernel_1354074/3992563308.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
# /tmp/ipykernel_1354074/3992563308.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["step1_CE"] = df_cas["CE"]
# /tmp/ipykernel_1354074/3992563308.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /tmp/ipykernel_1354074/3992563308.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["NCE"] = 20.0 # actually stepped NCE 20/35/50
# /tmp/ipykernel_1354074/3992563308.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
# /tmp/ipykernel_1354074/3992563308.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["step1_CE"] = df_cas["CE"]
# /tmp/ipykernel_1354074/3992563308.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)

# %%
# LOG = pd.DataFrame(results)
# eval_columns = LOG.columns[3:]

# home_path = f"{home}/data/metabolites/benchmarking/"
# NAME = model_params["gnn_type"] + "_depth.csv"
# for col in eval_columns:
#     LOG[col] = LOG[col].apply(lambda x: str(list(x)))
# LOG.to_csv(home_path + NAME, index=False, sep="\t")

# %%
# LOGIC = pd.read_csv(home_path + NAME, sep="\t")
# for col in eval_columns:
#     LOGIC[col] = LOGIC[col].apply(lambda x: ast.literal_eval(x.replace('nan', 'None')))

# LOGIC[eval_columns] = LOGIC[eval_columns].apply(lambda x: x.apply(np.median))
# LOGIC

# %%
LOG = pd.DataFrame(results)
eval_columns = LOG.columns[1:]
LOG[eval_columns] = LOG[eval_columns].apply(lambda x: x.apply(np.median))

LOG
# Out:
#                                                model  validation      test  \
# 0  GNNCompiler(\n  (node_embedding): FeatureEmbed...    0.694766  0.712094
#
#    casmi16   casmi22  casmi16+  casmi16-  casmi22+  casmi22-
# 0  0.65849  0.186936  0.607794  0.759366  0.169656  0.214083

# %%
raise KeyboardInterrupt("Stop before overwriting previous saves. Only continue by creating a new version")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 raise KeyboardInterrupt("Stop before overwriting previous saves. Only continue by creating a new version")
#
# KeyboardInterrupt: Stop before overwriting previous saves. Only continue by creating a new version

# %%
model.model_params
# Out:
# {'param_tag': 'default',
#  'gnn_type': 'RGCNConv',
#  'depth': 6,
#  'hidden_dimension': 300,
#  'dense_layers': 2,
#  'embedding_aggregation': 'concat',
#  'embedding_dimension': 300,
#  'input_dropout': 0.2,
#  'latent_dropout': 0.1,
#  'node_feature_layout': {'symbol': 10, 'num_hydrogen': 5, 'ring_type': 5},
#  'edge_feature_layout': {'bond_type': 4, 'ring_type': 5},
#  'static_feature_dimension': 9,
#  'static_rt_feature_dimension': 8,
#  'output_dimension': 10,
#  'atom_features': ['bond_type', 'ring_type'],
#  'setup_features': ['collision_energy',
#   'molecular_weight',
#   'precursor_mode',
#   'instrument'],
#  'rt_features': ['molecular_weight', 'precursor_mode', 'instrument']}

# %%
model_tag = "merged" if lib == "NIST/MSDIAL" else "OS" if lib == "MSDIAL" else "NIST"
depth = model_params["depth"]
month = "June24"
model_name = f"v0.0.1_2_{model_tag}_depth{depth}_{month}"
model_params["name"] = model_name # TODO CHANGE IN CLASS
model.model_params["name"] = model_name
MODEL_PATH = f"{home}/data/metabolites/pretrained_models/{model_name}.pt"

# %%
save_model = False
if save_model:
    model.save(MODEL_PATH)
    print(f"Saved to {MODEL_PATH}")

# %%
raise KeyboardInterrupt()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 raise KeyboardInterrupt()
#
# KeyboardInterrupt:

# %%
from fiora.GNN.GNNModules import GNNCompiler

# %%
dev="cuda:1"
model = GNNCompiler.load(MODEL_PATH)
model.eval()
model = model.to(dev)

# %%
print(np.median(test_model(model, df_train[df_train["dataset"]== "validation"])))
print(np.median(test_model(model, df_test)))
# Out:
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# 0.7036478781157653
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# 0.7243129555173167

# %%
print(np.median(test_cas16(model, df_cas[df_cas["Precursor_type"] == "[M+H]+"])))
print(np.median(test_cas16(model, df_cas[df_cas["Precursor_type"] == "[M-H]-"])))
# Out:
# /tmp/ipykernel_1354074/3992563308.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["NCE"] = 20.0 # actually stepped NCE 20/35/50
# /tmp/ipykernel_1354074/3992563308.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
# /tmp/ipykernel_1354074/3992563308.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["step1_CE"] = df_cas["CE"]
# /tmp/ipykernel_1354074/3992563308.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# 0.6402433230853445
# /tmp/ipykernel_1354074/3992563308.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["NCE"] = 20.0 # actually stepped NCE 20/35/50
# /tmp/ipykernel_1354074/3992563308.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["CE"] = df_cas[["NCE", "PRECURSOR_MZ"]].apply(lambda x: NCE_to_eV(x["NCE"], x["PRECURSOR_MZ"]), axis=1)
# /tmp/ipykernel_1354074/3992563308.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["step1_CE"] = df_cas["CE"]
# /tmp/ipykernel_1354074/3992563308.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cas["summary"] = df_cas.apply(lambda x: {key: x[name] for key, name in metadata_key_map16.items()}, axis=1)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# 0.7282791757138194

# %%
import json
with open(MODEL_PATH.replace(".pt", "_params.json"), 'r') as fp:
    p = json.load(fp)
hh = GNNCompiler(p)
hh.load_state_dict(torch.load(MODEL_PATH.replace(".pt", "_state.pt")))
hh.eval()
hh = hh.to(dev)

# %%
np.median(test_model(mymy, df_test))
# Out:
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# 0.7243129568222673

# %%
raise KeyboardInterrupt("TODO")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ynowatzk/repos/metabolites/notebooks/train_model.ipynb Cell 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bsv2111/home/ynowatzk/repos/metabolites/notebooks/train_model.ipynb#X51sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> raise KeyboardInterrupt("TODO")
#
# KeyboardInterrupt: TODO

# %%
## prepare output for for CFM-ID
import os
save_df = False
cfm_directory = f"{home}/data/metabolites/cfm-id/"
name = "test_split_negative_solutions_cfm.txt"
df_cfm = df_test[["group_id", "SMILES", "Precursor_type"]]
df_n = df_cfm[df_cfm["Precursor_type"] == "[M-H]-"].drop_duplicates(subset='group_id', keep='first')
df_p = df_cfm[df_cfm["Precursor_type"] == "[M+H]+"].drop_duplicates(subset='group_id', keep='first')

print(df_n.head())

if save_df:
    file = os.path.join(cfm_directory, name)
    df_n[["group_id", "SMILES"]].to_csv(file, index=False, header=False, sep=" ")
    
    name = name.replace("negative", "positive")
    file = os.path.join(cfm_directory, name)
    df_p[["group_id", "SMILES"]].to_csv(file, index=False, header=False, sep=" ")
# Out:
#       group_id                                             SMILES  \
# 173         15  CC1(C)S[C@@H]2[C@H](NC(=O)[C@H](N)c3ccccc3)C(=...
# 447         40  CCN(CC)CCCC(C)Nc(c21)c(c3)c(ccc(OC)3)nc(cc(Cl)...
# 1172       118                           N[C@@H](Cc1ccccc1)C(=O)O
# 1224       124               NC(CCC(=O)NC(CS)C(=O)NCC(=O)O)C(=O)O
# 1266       129          O=S(=O)(c1ccc(cc1)NC(=O)C)Nc1nc(cc(n1)C)C
#
#      Precursor_type
# 173          [M-H]-
# 447          [M-H]-
# 1172         [M-H]-
# 1224         [M-H]-
# 1266         [M-H]-

# %% [markdown]
# ### RT an CCS

# %%
import json
from fiora.GNN.GNNModules import GNNCompiler
from fiora.MS.SimulationFramework import SimulationFramework

# %%
# Load best model

dev="cuda:1"
MODEL_PATH = f"{home}/data/metabolites/pretrained_models/pre_package/{model_name}.pt"


try: 
    model = GNNCompiler.load(MODEL_PATH)
except:
    try:
        print(f"Warning: Failed loading the model {MODEL_PATH}. Fall back: Loading the model from state dictionary.")
        model = GNNCompiler.load_from_state_dict(MODEL_PATH)
        print("Model loaded from state dict without further errors.")
    except:
        raise NameError("Error: Failed loading from state dict.")
        

model.eval()
model = model.to(dev)

model.model_params
# Out:
# {'param_tag': 'default',
#  'gnn_type': 'RGCNConv',
#  'depth': 6,
#  'hidden_dimension': 300,
#  'dense_layers': 2,
#  'embedding_aggregation': 'concat',
#  'embedding_dimension': 300,
#  'input_dropout': 0.2,
#  'latent_dropout': 0.1,
#  'node_feature_layout': {'symbol': 10, 'num_hydrogen': 5, 'ring_type': 5},
#  'edge_feature_layout': {'bond_type': 4, 'ring_type': 5},
#  'static_feature_dimension': 9,
#  'static_rt_feature_dimension': 8,
#  'output_dimension': 10,
#  'atom_features': ['bond_type', 'ring_type'],
#  'setup_features': ['collision_energy',
#   'molecular_weight',
#   'precursor_mode',
#   'instrument'],
#  'rt_features': ['molecular_weight', 'precursor_mode', 'instrument'],
#  'name': 'v0.0.1_2_OS_depth6_June24'}

# %%
spectral_modules = ["node_embedding", "edge_embedding", "GNN_module", "edge_module", "precursor_module"]

for module in spectral_modules:
    model.freeze_submodule(module)

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"{name}: requires gradients")
    # else:
    #     print(f"{name}: does not require gradients (frozen)")
# Out:
# RT_module.dense_layers.0.weight: requires gradients
# RT_module.dense_layers.0.bias: requires gradients
# RT_module.dense_layers.1.weight: requires gradients
# RT_module.dense_layers.1.bias: requires gradients
# RT_module.output_layer.weight: requires gradients
# RT_module.output_layer.bias: requires gradients
# CCS_module.dense_layers.0.weight: requires gradients
# CCS_module.dense_layers.0.bias: requires gradients
# CCS_module.dense_layers.1.weight: requires gradients
# CCS_module.dense_layers.1.bias: requires gradients
# CCS_module.output_layer.weight: requires gradients
# CCS_module.output_layer.bias: requires gradients

# %%
df_train["RTorCCS"] = ~(df_train["RETENTIONTIME"].isna() & df_train["CCS"].isna())
# Out:
# /tmp/ipykernel_1354074/3180048748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_train["RTorCCS"] = ~(df_train["RETENTIONTIME"].isna() & df_train["CCS"].isna())

# %%
rt_index = df_train.drop_duplicates("group_id", keep="first")["RTorCCS"]
print("RT: ", sum(~df_train.drop_duplicates("group_id", keep="first")[rt_index]["RETENTIONTIME"].isna()))
print("CCS: ", sum(~df_train.drop_duplicates("group_id", keep="first")[rt_index]["CCS"].isna()))
df_rt = df_train.drop_duplicates("group_id", keep="first")[rt_index]
geo_data = df_rt["Metabolite"].apply(lambda x: x.as_geometric_data().to(dev)).values
print(f"Prepared training/validation with {len(geo_data)} data points")
# Out:
# RT:  452
# CCS:  2025
# Prepared training/validation with 2330 data points

# %%
sum(~df_rt[df_rt["dataset"] == "validation"]["RETENTIONTIME"].isna())
# Out:
# 56

# %%
rt_epochs = 500 # 300
rt_batch = 128
rt_lr = 0.005
def train_rt_model():        
    y_label = 'compiled_probsALL'
    optimizer = torch.optim.Adam(model.parameters(), lr=rt_lr)
    
    
    train_keys, val_keys = df_rt[df_rt["dataset"] == "training"]["group_id"].unique(), df_rt[df_rt["dataset"] == "validation"]["group_id"].unique()
    trainer = Trainer(geo_data, y_tag=y_label, problem_type="regression", train_keys=train_keys, val_keys=val_keys, metric_dict=None, split_by_group=True, seed=seed, device=dev)
    #scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.98) # worked well
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience = 8, factor=0.8, mode = 'min', verbose = True)

    
    checkpoints = trainer.train(model, optimizer, loss_fn, scheduler=scheduler, batch_size=rt_batch, epochs=rt_epochs, val_every_n_epochs=1, with_CCS=True, with_RT=True, rt_metric=True, masked_validation=False, tag=tag) #, mask_name="compiled_validation_maskALL")   
    
    return model, checkpoints

# %%
model, cp = train_rt_model() #Val RMSE 14.05 is too beat.
# Out:
# Using pre-arranged train/validation set
# 	Validation RMSE: 51.4912014
# 	Validation RMSE: 31.576728
# 	Validation RMSE: 30.020307
# 	Validation RMSE: 28.329020
# 	Validation RMSE: 29.014440
# 	Validation RMSE: 26.215808
# 	Validation RMSE: 25.327306
# 	Validation RMSE: 24.337364
# 	Validation RMSE: 23.239023
# 	Validation RMSE: 23.3274359
# 	Validation RMSE: 21.3999923
# 	Validation RMSE: 22.2746828
# 	Validation RMSE: 21.2214664
# 	Validation RMSE: 20.7922288
# 	Validation RMSE: 20.7591655
# 	Validation RMSE: 19.9528860
# 	Validation RMSE: 20.7991233
# 	Validation RMSE: 21.0681137
# 	Validation RMSE: 20.0268826
# 	Validation RMSE: 19.4384678
# 	Validation RMSE: 19.9252530
# 	Validation RMSE: 22.0997200
# 	Validation RMSE: 19.3913926
# 	Validation RMSE: 19.5730665
# 	Validation RMSE: 19.1361073
# 	Validation RMSE: 19.2806493
# 	Validation RMSE: 18.0846375
# 	Validation RMSE: 18.8292679
# 	Validation RMSE: 19.4978059
# 	Validation RMSE: 19.4351090
# 	Validation RMSE: 18.8629315
# 	Validation RMSE: 20.1378301
# 	Validation RMSE: 18.4633560
# 	Validation RMSE: 19.6806525
# 	Validation RMSE: 19.5842861
# 	Validation RMSE: 17.4924985
# 	Validation RMSE: 17.6907701
# 	Validation RMSE: 19.4321034
# 	Validation RMSE: 17.7657186
# 	Validation RMSE: 21.3703834
# 	Validation RMSE: 18.0041046
# 	Validation RMSE: 17.1392623
# 	Validation RMSE: 17.2709821
# 	Validation RMSE: 17.8009476
# 	Validation RMSE: 17.8686320
# 	Validation RMSE: 17.7635247
# 	Validation RMSE: 16.9340056
# 	Validation RMSE: 16.8366702
# 	Validation RMSE: 17.9866219
# 	Validation RMSE: 18.6290815
# 	Validation RMSE: 16.8053210
# 	Validation RMSE: 16.3676115
# 	Validation RMSE: 18.1417055
# 	Validation RMSE: 23.5679581
# 	Validation RMSE: 17.7675076
# 	Validation RMSE: 17.5816711
# 	Validation RMSE: 19.6387976
# 	Validation RMSE: 17.1190738
# 	Validation RMSE: 20.7626635
# 	Validation RMSE: 21.7327695
# 	Validation RMSE: 18.9971268
# Epoch 00061: reducing learning rate of group 0 to 4.0000e-03.
# 	Validation RMSE: 16.3871469
# 	Validation RMSE: 15.7182499
# 	Validation RMSE: 15.7924854
# 	Validation RMSE: 15.9845144
# 	Validation RMSE: 15.4600117
# 	Validation RMSE: 16.4594495
# 	Validation RMSE: 15.5325310
# 	Validation RMSE: 16.1077141
# 	Validation RMSE: 15.7710070
# 	Validation RMSE: 15.4353020
# 	Validation RMSE: 15.5591909
# 	Validation RMSE: 15.1820528
# 	Validation RMSE: 15.2073235
# 	Validation RMSE: 15.5955452
# 	Validation RMSE: 15.2437026
# 	Validation RMSE: 15.3287191
# 	Validation RMSE: 16.5183591
# 	Validation RMSE: 15.3098276
# 	Validation RMSE: 15.4918712
# 	Validation RMSE: 14.8244530
# 	Validation RMSE: 14.8048197
# 	Validation RMSE: 14.6577834
# 	Validation RMSE: 14.9636546
# 	Validation RMSE: 15.1468421
# 	Validation RMSE: 14.0632730
# 	Validation RMSE: 14.7169645
# 	Validation RMSE: 14.1742401
# 	Validation RMSE: 15.0665470
# 	Validation RMSE: 14.3608166
# 	Validation RMSE: 15.3355678
# 	Validation RMSE: 13.9593622
# 	Validation RMSE: 15.4880888
# 	Validation RMSE: 14.5801318
# 	Validation RMSE: 13.9753414
# 	Validation RMSE: 14.5089203
# 	Validation RMSE: 16.5961037
# 	Validation RMSE: 15.9087942
# 	Validation RMSE: 14.4155922
# 	Validation RMSE: 15.28549108
# 	Validation RMSE: 14.43525384
# Epoch 00101: reducing learning rate of group 0 to 3.2000e-03.
# 	Validation RMSE: 14.90761595
# 	Validation RMSE: 14.56810689
# 	Validation RMSE: 14.01627308
# 	Validation RMSE: 14.87077939
# 	Validation RMSE: 14.00733662
# 	Validation RMSE: 13.87063486
# 	Validation RMSE: 14.04666488
# 	Validation RMSE: 13.65770271
# 	Validation RMSE: 14.01597824
# 	Validation RMSE: 14.14760162
# 	Validation RMSE: 14.02606079
# 	Validation RMSE: 13.91044916
# 	Validation RMSE: 13.61795418
# 	Validation RMSE: 13.68837748
# 	Validation RMSE: 13.10163867
# 	Validation RMSE: 14.05162073
# 	Validation RMSE: 13.91073311
# 	Validation RMSE: 13.29148023
# 	Validation RMSE: 13.98692150
# 	Validation RMSE: 14.61868499
# 	Validation RMSE: 13.81633006
# 	Validation RMSE: 13.68326392
# 	Validation RMSE: 13.49724887
# 	Validation RMSE: 14.42846326
# Epoch 00125: reducing learning rate of group 0 to 2.5600e-03.
# 	Validation RMSE: 13.43522617
# 	Validation RMSE: 13.58254546
# 	Validation RMSE: 13.47341074
# 	Validation RMSE: 13.42646944
# 	Validation RMSE: 14.09599870
# 	Validation RMSE: 13.36943178
# 	Validation RMSE: 12.84876511
# 	Validation RMSE: 13.49089356
# 	Validation RMSE: 13.99837133
# 	Validation RMSE: 13.69173350
# 	Validation RMSE: 12.78548472
# 	Validation RMSE: 13.41084635
# 	Validation RMSE: 13.59318073
# 	Validation RMSE: 13.01954120
# 	Validation RMSE: 12.97123596
# 	Validation RMSE: 13.24594719
# 	Validation RMSE: 12.78813282
# 	Validation RMSE: 13.44123326
# 	Validation RMSE: 13.04695896
# 	Validation RMSE: 12.45596500
# 	Validation RMSE: 12.83052372
# 	Validation RMSE: 12.59655372
# 	Validation RMSE: 12.71452734
# 	Validation RMSE: 12.93282175
# 	Validation RMSE: 13.33048115
# 	Validation RMSE: 14.28702932
# 	Validation RMSE: 13.14446814
# 	Validation RMSE: 12.94329858
# 	Validation RMSE: 14.09359723
# Epoch 00154: reducing learning rate of group 0 to 2.0480e-03.
# 	Validation RMSE: 15.42900219
# 	Validation RMSE: 12.86933990
# 	Validation RMSE: 12.94514333
# 	Validation RMSE: 12.70582503
# 	Validation RMSE: 12.95354505
# 	Validation RMSE: 12.70583433
# 	Validation RMSE: 13.27345276
# 	Validation RMSE: 12.64854056
# 	Validation RMSE: 12.98650372
# Epoch 00163: reducing learning rate of group 0 to 1.6384e-03.
# 	Validation RMSE: 13.23143464
# 	Validation RMSE: 12.28752452
# 	Validation RMSE: 12.4293327
# 	Validation RMSE: 12.5498496
# 	Validation RMSE: 12.7365364
# 	Validation RMSE: 12.5004453
# 	Validation RMSE: 12.3892187
# 	Validation RMSE: 12.2390560
# 	Validation RMSE: 12.4658235
# 	Validation RMSE: 12.9656564
# 	Validation RMSE: 12.59110924
# 	Validation RMSE: 12.4460567
# 	Validation RMSE: 12.2186723
# 	Validation RMSE: 12.5967411
# 	Validation RMSE: 12.3329655
# 	Validation RMSE: 12.3537144
# 	Validation RMSE: 12.3291779
# 	Validation RMSE: 13.1762766
# 	Validation RMSE: 13.1627699
# 	Validation RMSE: 12.5042330
# 	Validation RMSE: 12.4836434
# 	Validation RMSE: 12.5967658
# Epoch 00185: reducing learning rate of group 0 to 1.3107e-03.
# 	Validation RMSE: 12.6706246
# 	Validation RMSE: 12.9575641
# 	Validation RMSE: 12.1163947
# 	Validation RMSE: 12.4849610
# 	Validation RMSE: 12.8474816
# 	Validation RMSE: 12.2128250
# 	Validation RMSE: 12.4715147
# 	Validation RMSE: 12.3832526
# 	Validation RMSE: 12.5771647
# 	Validation RMSE: 12.3521066
# 	Validation RMSE: 13.0605351
# 	Validation RMSE: 12.50226084
# Epoch 00197: reducing learning rate of group 0 to 1.0486e-03.
# 	Validation RMSE: 12.9850313
# 	Validation RMSE: 12.2271680
# 	Validation RMSE: 12.2700051
# 	Validation RMSE: 12.3095979
# 	Validation RMSE: 12.3801334
# 	Validation RMSE: 12.5371561
# 	Validation RMSE: 12.5178107
# 	Validation RMSE: 13.0485689
# 	Validation RMSE: 13.28201282
# Epoch 00206: reducing learning rate of group 0 to 8.3886e-04.
# 	Validation RMSE: 12.0127484
# 	Validation RMSE: 12.0426623
# 	Validation RMSE: 11.8982868
# 	Validation RMSE: 12.6867458
# 	Validation RMSE: 12.0523288
# 	Validation RMSE: 11.9520413
# 	Validation RMSE: 12.2598481
# 	Validation RMSE: 12.2400289
# 	Validation RMSE: 11.8704438
# 	Validation RMSE: 11.9390594
# 	Validation RMSE: 12.2377823
# 	Validation RMSE: 12.1294889
# 	Validation RMSE: 12.2413413
# 	Validation RMSE: 12.0791856
# 	Validation RMSE: 12.1143773
# 	Validation RMSE: 12.0637019
# 	Validation RMSE: 12.1102220
# 	Validation RMSE: 12.0591355
# Epoch 00224: reducing learning rate of group 0 to 6.7109e-04.
# 	Validation RMSE: 11.8005984
# 	Validation RMSE: 11.8407242
# 	Validation RMSE: 11.9194764
# 	Validation RMSE: 11.8626321
# 	Validation RMSE: 12.0895800
# 	Validation RMSE: 11.9604856
# 	Validation RMSE: 11.8346878
# 	Validation RMSE: 11.8220837
# 	Validation RMSE: 12.0211688
# 	Validation RMSE: 11.8204079
# Epoch 00234: reducing learning rate of group 0 to 5.3687e-04.
# 	Validation RMSE: 11.8565936
# 	Validation RMSE: 11.9226369
# 	Validation RMSE: 11.8245671
# 	Validation RMSE: 11.6561494
# 	Validation RMSE: 11.8319860
# 	Validation RMSE: 11.7613319
# 	Validation RMSE: 11.8672017
# 	Validation RMSE: 12.1018576
# 	Validation RMSE: 11.9175220
# 	Validation RMSE: 11.9527886
# 	Validation RMSE: 11.7385418
# 	Validation RMSE: 11.7301126
# 	Validation RMSE: 11.8261408
# Epoch 00247: reducing learning rate of group 0 to 4.2950e-04.
# 	Validation RMSE: 11.6814069
# 	Validation RMSE: 11.4681411
# 	Validation RMSE: 11.5063859
# 	Validation RMSE: 11.7275898
# 	Validation RMSE: 11.6698870
# 	Validation RMSE: 11.6011252
# 	Validation RMSE: 11.6291341
# 	Validation RMSE: 11.6260794
# 	Validation RMSE: 11.7649901
# 	Validation RMSE: 11.4566063
# 	Validation RMSE: 11.5283305
# 	Validation RMSE: 11.8412325
# 	Validation RMSE: 11.8553313
# 	Validation RMSE: 11.7012772
# 	Validation RMSE: 11.5564858
# 	Validation RMSE: 11.5558231
# 	Validation RMSE: 11.6633069
# 	Validation RMSE: 11.6283561
# 	Validation RMSE: 11.6415734
# Epoch 00266: reducing learning rate of group 0 to 3.4360e-04.
# 	Validation RMSE: 11.6221045
# 	Validation RMSE: 11.6684170
# 	Validation RMSE: 11.8264001
# 	Validation RMSE: 11.6428372
# 	Validation RMSE: 11.6886431
# 	Validation RMSE: 11.5105194
# 	Validation RMSE: 12.0523974
# 	Validation RMSE: 11.7368608
# 	Validation RMSE: 11.7136898
# Epoch 00275: reducing learning rate of group 0 to 2.7488e-04.
# 	Validation RMSE: 11.5428718
# 	Validation RMSE: 11.4175279
# 	Validation RMSE: 11.3842873
# 	Validation RMSE: 11.3819757
# 	Validation RMSE: 11.4444575
# 	Validation RMSE: 11.5429992
# 	Validation RMSE: 11.5155588
# 	Validation RMSE: 11.6399044
# 	Validation RMSE: 11.5503307
# 	Validation RMSE: 11.7092645
# 	Validation RMSE: 11.5937663
# 	Validation RMSE: 11.4908409
# 	Validation RMSE: 11.5683814
# Epoch 00288: reducing learning rate of group 0 to 2.1990e-04.
# 	Validation RMSE: 11.5432700
# 	Validation RMSE: 11.5672233
# 	Validation RMSE: 11.6995196
# 	Validation RMSE: 11.5934064
# 	Validation RMSE: 11.5218059
# 	Validation RMSE: 11.6161812
# 	Validation RMSE: 11.6256564
# 	Validation RMSE: 11.5798261
# 	Validation RMSE: 11.7031074
# Epoch 00297: reducing learning rate of group 0 to 1.7592e-04.
# 	Validation RMSE: 11.4554962
# 	Validation RMSE: 11.5309382
# 	Validation RMSE: 11.4067384
# 	Validation RMSE: 11.4227597
# 	Validation RMSE: 11.5150474
# 	Validation RMSE: 11.5527053
# 	Validation RMSE: 11.7106235
# 	Validation RMSE: 11.5853550
# 	Validation RMSE: 11.5312959
# Epoch 00306: reducing learning rate of group 0 to 1.4074e-04.
# 	Validation RMSE: 11.5033225
# 	Validation RMSE: 11.5111632
# 	Validation RMSE: 11.4863852
# 	Validation RMSE: 11.6097857
# 	Validation RMSE: 11.4835345
# 	Validation RMSE: 11.4571500
# 	Validation RMSE: 11.5792431
# 	Validation RMSE: 11.7403127
# 	Validation RMSE: 11.5831003
# Epoch 00315: reducing learning rate of group 0 to 1.1259e-04.
# 	Validation RMSE: 11.5791479
# 	Validation RMSE: 11.5644258
# 	Validation RMSE: 11.5698601
# 	Validation RMSE: 11.5514067
# 	Validation RMSE: 11.5042472
# 	Validation RMSE: 11.4862861
# 	Validation RMSE: 11.5462737
# 	Validation RMSE: 11.4138854
# 	Validation RMSE: 11.4489651
# Epoch 00324: reducing learning rate of group 0 to 9.0072e-05.
# 	Validation RMSE: 11.3195241
# 	Validation RMSE: 11.4247488
# 	Validation RMSE: 11.5398615
# 	Validation RMSE: 11.4713925
# 	Validation RMSE: 11.4359935
# 	Validation RMSE: 11.4140534
# 	Validation RMSE: 11.5427932
# 	Validation RMSE: 11.4638151
# 	Validation RMSE: 11.6844853
# 	Validation RMSE: 11.4044401
# Epoch 00334: reducing learning rate of group 0 to 7.2058e-05.
# 	Validation RMSE: 11.3931297
# 	Validation RMSE: 11.5224178
# 	Validation RMSE: 11.4510663
# 	Validation RMSE: 11.4627237
# 	Validation RMSE: 11.4483806
# 	Validation RMSE: 11.4485192
# 	Validation RMSE: 11.4944813
# 	Validation RMSE: 11.4717986
# 	Validation RMSE: 11.5354264
# Epoch 00343: reducing learning rate of group 0 to 5.7646e-05.
# 	Validation RMSE: 11.5446502
# 	Validation RMSE: 11.4613696
# 	Validation RMSE: 11.4181671
# 	Validation RMSE: 11.5252917
# 	Validation RMSE: 11.4047159
# 	Validation RMSE: 11.4898064
# 	Validation RMSE: 11.4291609
# 	Validation RMSE: 11.4064649
# 	Validation RMSE: 11.5399447
# Epoch 00352: reducing learning rate of group 0 to 4.6117e-05.
# 	Validation RMSE: 11.4588295
# 	Validation RMSE: 11.4283531
# 	Validation RMSE: 11.4229204
# 	Validation RMSE: 11.3901067
# 	Validation RMSE: 11.4542738
# 	Validation RMSE: 11.4339391
# 	Validation RMSE: 11.4103137
# 	Validation RMSE: 11.4294048
# 	Validation RMSE: 11.3916887
# Epoch 00361: reducing learning rate of group 0 to 3.6893e-05.
# 	Validation RMSE: 11.4338680
# 	Validation RMSE: 11.3902802
# 	Validation RMSE: 11.4003563
# 	Validation RMSE: 11.4088205
# 	Validation RMSE: 11.4385295
# 	Validation RMSE: 11.5165007
# 	Validation RMSE: 11.5016802
# 	Validation RMSE: 11.4860206
# 	Validation RMSE: 11.5105328
# Epoch 00370: reducing learning rate of group 0 to 2.9515e-05.
# 	Validation RMSE: 11.4778914
# 	Validation RMSE: 11.4038112
# 	Validation RMSE: 11.4107858
# 	Validation RMSE: 11.4274829
# 	Validation RMSE: 11.3988509
# 	Validation RMSE: 11.4083197
# 	Validation RMSE: 11.4199100
# 	Validation RMSE: 11.4198574
# 	Validation RMSE: 11.4237414
# Epoch 00379: reducing learning rate of group 0 to 2.3612e-05.
# 	Validation RMSE: 11.3991712
# 	Validation RMSE: 11.3925169
# 	Validation RMSE: 11.4161484
# 	Validation RMSE: 11.4620514
# 	Validation RMSE: 11.4247659
# 	Validation RMSE: 11.4423956
# 	Validation RMSE: 11.5095984
# 	Validation RMSE: 11.4886896
# 	Validation RMSE: 11.4525323
# Epoch 00388: reducing learning rate of group 0 to 1.8889e-05.
# 	Validation RMSE: 11.4393339
# 	Validation RMSE: 11.4512592
# 	Validation RMSE: 11.4379491
# 	Validation RMSE: 11.4102744
# 	Validation RMSE: 11.3880797
# 	Validation RMSE: 11.3798428
# 	Validation RMSE: 11.3924783
# 	Validation RMSE: 11.3895892
# 	Validation RMSE: 11.3707626
# Epoch 00397: reducing learning rate of group 0 to 1.5112e-05.
# 	Validation RMSE: 11.4358183
# 	Validation RMSE: 11.4430775
# 	Validation RMSE: 11.4096952
# 	Validation RMSE: 11.4074235
# 	Validation RMSE: 11.3936753
# 	Validation RMSE: 11.3796054
# 	Validation RMSE: 11.3766409
# 	Validation RMSE: 11.3884301
# 	Validation RMSE: 11.4025160
# Epoch 00406: reducing learning rate of group 0 to 1.2089e-05.
# 	Validation RMSE: 11.4186879
# 	Validation RMSE: 11.4087854
# 	Validation RMSE: 11.4410224
# 	Validation RMSE: 11.4453499
# 	Validation RMSE: 11.4251939
# 	Validation RMSE: 11.4237552
# 	Validation RMSE: 11.4338956
# 	Validation RMSE: 11.4184728
# 	Validation RMSE: 11.4163830
# Epoch 00415: reducing learning rate of group 0 to 9.6714e-06.
# 	Validation RMSE: 11.4095777
# 	Validation RMSE: 11.4222556
# 	Validation RMSE: 11.4531559
# 	Validation RMSE: 11.4612766
# 	Validation RMSE: 11.4503906
# 	Validation RMSE: 11.4308333
# 	Validation RMSE: 11.4184151
# 	Validation RMSE: 11.4290937
# 	Validation RMSE: 11.4354175
# Epoch 00424: reducing learning rate of group 0 to 7.7371e-06.
# 	Validation RMSE: 11.4312841
# 	Validation RMSE: 11.4071506
# 	Validation RMSE: 11.3961792
# 	Validation RMSE: 11.3927906
# 	Validation RMSE: 11.4006747
# 	Validation RMSE: 11.4014560
# 	Validation RMSE: 11.4130366
# 	Validation RMSE: 11.4107336
# 	Validation RMSE: 11.3990111
# Epoch 00433: reducing learning rate of group 0 to 6.1897e-06.
# 	Validation RMSE: 11.4057565
# 	Validation RMSE: 11.4078796
# 	Validation RMSE: 11.4010489
# 	Validation RMSE: 11.4058758
# 	Validation RMSE: 11.3977313
# 	Validation RMSE: 11.3973264
# 	Validation RMSE: 11.4091055
# 	Validation RMSE: 11.4189413
# 	Validation RMSE: 11.4217091
# Epoch 00442: reducing learning rate of group 0 to 4.9518e-06.
# 	Validation RMSE: 11.4199078
# 	Validation RMSE: 11.4275777
# 	Validation RMSE: 11.4268424
# 	Validation RMSE: 11.4217344
# 	Validation RMSE: 11.4341380
# 	Validation RMSE: 11.4281145
# 	Validation RMSE: 11.4165142
# 	Validation RMSE: 11.3992232
# 	Validation RMSE: 11.3995980
# Epoch 00451: reducing learning rate of group 0 to 3.9614e-06.
# 	Validation RMSE: 11.4046032
# 	Validation RMSE: 11.4002557
# 	Validation RMSE: 11.4021960
# 	Validation RMSE: 11.4035478
# 	Validation RMSE: 11.4022117
# 	Validation RMSE: 11.4093673
# 	Validation RMSE: 11.4099180
# 	Validation RMSE: 11.4053551
# 	Validation RMSE: 11.4012168
# Epoch 00460: reducing learning rate of group 0 to 3.1691e-06.
# 	Validation RMSE: 11.3977054
# 	Validation RMSE: 11.3987581
# 	Validation RMSE: 11.4091365
# 	Validation RMSE: 11.4109447
# 	Validation RMSE: 11.4091861
# 	Validation RMSE: 11.4073571
# 	Validation RMSE: 11.4108169
# 	Validation RMSE: 11.4131224
# 	Validation RMSE: 11.4215871
# Epoch 00469: reducing learning rate of group 0 to 2.5353e-06.
# 	Validation RMSE: 11.4248457
# 	Validation RMSE: 11.4216615
# 	Validation RMSE: 11.4153022
# 	Validation RMSE: 11.4153753
# 	Validation RMSE: 11.4169816
# 	Validation RMSE: 11.4127123
# 	Validation RMSE: 11.4110780
# 	Validation RMSE: 11.4083448
# 	Validation RMSE: 11.4087103
# Epoch 00478: reducing learning rate of group 0 to 2.0282e-06.
# 	Validation RMSE: 11.4089273
# 	Validation RMSE: 11.4090583
# 	Validation RMSE: 11.4092489
# 	Validation RMSE: 11.4100190
# 	Validation RMSE: 11.4127810
# 	Validation RMSE: 11.4113598
# 	Validation RMSE: 11.4127602
# 	Validation RMSE: 11.4138572
# 	Validation RMSE: 11.4165252
# Epoch 00487: reducing learning rate of group 0 to 1.6226e-06.
# 	Validation RMSE: 11.4174635
# 	Validation RMSE: 11.4193141
# 	Validation RMSE: 11.4204302
# 	Validation RMSE: 11.4231237
# 	Validation RMSE: 11.4189119
# 	Validation RMSE: 11.4158258
# 	Validation RMSE: 11.4183053
# 	Validation RMSE: 11.4169241
# 	Validation RMSE: 11.4130993
# Epoch 00496: reducing learning rate of group 0 to 1.2981e-06.
# 	Validation RMSE: 11.4105000
# 	Validation RMSE: 11.4084972
# 	Validation RMSE: 11.4094407
# 	Validation RMSE: 11.4113652
# Finished Training!

# %%
print(cp, np.sqrt(cp["val_loss"]))
model = GNNCompiler.load(cp["file"])
# Out:
# {'epoch': 325, 'val_loss': 128.1314697265625, 'file': '../../checkpoint_training.best.pt'} 11.31951720377519

# %%
#raise KeyboardInterrupt("Save file") #TODO
MODEL_PATH = f"{home}/data/metabolites/pretrained_models/pre_package/{model_name}+CCS+RT.pt"
model.save(MODEL_PATH)

# %%
val_df = test_model(model, df_train[df_train["dataset"]== "validation"], return_df=True)
test_df = test_model(model, df_test, return_df=True)
casmi16_df = test_cas16(model, return_df=True)    
val_df["Dataset"] = "Val"
casmi16_df["Dataset"] = "CASMI 22"
test_df["Dataset"] = "Test split"
# Out:
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/SimulationFramework.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame(columns=[x + suffix for x in ["cosine_similarity", "kl_div", "sim_peaks", "spectral_cosine", "spectral_sqrt_cosine", "spectral_sqrt_cosine_wo_prec", "spectral_refl_cosine", "spectral_bias", "spectral_sqrt_bias", "spectral_sqrt_bias_wo_prec", "spectral_refl_bias", "steins_cosine", "steins_bias", "RT_pred", "RT_dif", "CCS_pred"]])])
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:27: RuntimeWarning: divide by zero encountered in divide
#   vec_other = vec_other / np.linalg.norm(vec_other)
# /home/ynowatzk/repos/fiora/fiora/MS/spectral_scores.py:26: RuntimeWarning: divide by zero encountered in divide
#   vec = vec / np.linalg.norm(vec)

# %%
import seaborn as sns
from fiora.visualization.define_colors import *

fig, axs = plt.subplots(2, 1, figsize=(12, 14), gridspec_kw={'height_ratios': [1, 5]}, sharex=True)
plt.subplots_adjust(wspace=0.1, hspace=0.05)
set_light_theme()

df_test_unique = test_df.drop_duplicates(subset="group_id", keep='first')


#sns.histplot(ax=axs[0], data=df_val_unique, x="coverage", binwidth=0.02, kde_kws={"bw_adjust": 0.1}, multiple="stack", kde=True, color="black", palette=["black", "gray"]) #hue="Precursor_type", 
sns.kdeplot(ax=axs[0], data=df_test_unique, x="RETENTIONTIME", bw_adjust=0.25, color="gray", fill=True)#, multiple="stack") #hue="Precursor_type", 
sns.kdeplot(ax=axs[0], data=df_test_unique, x="RETENTIONTIME", bw_adjust=0.25, color="gray") #, multiple="stack") #hue="Precursor_type", 

axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)


sns.scatterplot(ax=axs[1], data=df_test_unique, x="RETENTIONTIME", y="RT_pred", color="gray")#, hue="library", palette=tri_palette,  style="library", color="gray")
axs[1].set_ylim([0,df_test_unique["RETENTIONTIME"].max() + 1 ])
axs[1].set_xlim([0,df_test_unique["RETENTIONTIME"].max() + 1])
axs[1].set_ylabel("Predicted retention time")
axs[1].set_xlabel("Observed retention time")
line = [0, 100]
sns.lineplot(ax=axs[1], x=line, y=line, color="black")
sns.lineplot(ax=axs[1], x=line, y=[x + 20/60.0 for x in line], color="black", linestyle='--')
sns.lineplot(ax=axs[1], x=line, y=[x - 20/60.0 for x in line], color="black", linestyle='--')
plt.show()

# %%
# TODO NEXT UP!!
fig, axs = plt.subplots(2, 1, figsize=(12, 14), gridspec_kw={'height_ratios': [1, 5]}, sharex=True)
plt.subplots_adjust(wspace=0.1, hspace=0.05)

df_test_unique = test_df.drop_duplicates(subset='group_id', keep='first')
CCS = pd.concat([df_test_unique[["CCS", "CCS_pred", "Dataset"]], casmi16_df[["CCS", "CCS_pred", "Dataset"]]], ignore_index=True) #


#sns.histplot(ax=axs[0], data=df_val_unique, x="coverage", binwidth=0.02, kde_kws={"bw_adjust": 0.1}, multiple="stack", kde=True, color="black", palette=["black", "gray"]) #hue="Precursor_type", 
sns.kdeplot(ax=axs[0], data=CCS, x="CCS", bw_adjust=0.35, color="black", multiple="stack", hue="Dataset", palette=tri_palette, edgecolor="white") #hue="Precursor_type", palette=["black", "gray"]) #hue="Precursor_type", 
axs[0].spines['top'].set_visible(False)
axs[0].spines['right'].set_visible(False)


sns.scatterplot(ax=axs[1], data=CCS, x="CCS", y="CCS_pred", hue="Dataset", palette=tri_palette, style="Dataset", markers=[".", "X", "*"], color="gray", s=25, linewidth=.0)#, color="blue", edgecolor="blue")#, 
axs[1].set_ylim([df_test_unique["CCS"].min() - 10,df_test_unique["CCS"].max() + 10])
axs[1].set_xlim([df_test_unique["CCS"].min() - 10,df_test_unique["CCS"].max() + 10])
axs[1].set_ylabel("Predicted CCS")
axs[1].set_xlabel("Observed CCS")
line=[df_test_unique["CCS"].min() - 10,df_test_unique["CCS"].max() + 10]
sns.lineplot(ax=axs[1], x=line, y=line, color="black")
sns.lineplot(ax=axs[1], x=line, y=[1.1*x for x in line], color="black", linestyle='--')
sns.lineplot(ax=axs[1], x=line, y=[0.9*x for x in line], color="black", linestyle='--')
plt.show()
# Out:
# /tmp/ipykernel_1354074/519092727.py:10: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.kdeplot(ax=axs[0], data=CCS, x="CCS", bw_adjust=0.35, color="black", multiple="stack", hue="Dataset", palette=tri_palette, edgecolor="white") #hue="Precursor_type", palette=["black", "gray"]) #hue="Precursor_type",
# /tmp/ipykernel_1354074/519092727.py:15: UserWarning: The palette list has more values (3) than needed (2), which may not be intended.
#   sns.scatterplot(ax=axs[1], data=CCS, x="CCS", y="CCS_pred", hue="Dataset", palette=tri_palette, style="Dataset", markers=[".", "X", "*"], color="gray", s=25, linewidth=.0)#, color="blue", edgecolor="blue")#,
# /tmp/ipykernel_1354074/519092727.py:15: UserWarning: The markers list has more values (3) than needed (2), which may not be intended.
#   sns.scatterplot(ax=axs[1], data=CCS, x="CCS", y="CCS_pred", hue="Dataset", palette=tri_palette, style="Dataset", markers=[".", "X", "*"], color="gray", s=25, linewidth=.0)#, color="blue", edgecolor="blue")#,

# %%
print("TEST SPLIT:\n")
print("Pearson Corr Coef:")
print("GNN", np.corrcoef(df_test_unique.dropna(subset=["CCS"])["CCS"], df_test_unique.dropna(subset=["CCS"])["CCS_pred"].dropna(), dtype=float)[0,1])
print("LR ", np.corrcoef(df_test_unique.dropna(subset=["CCS"])["CCS"], df_test_unique.dropna(subset=["CCS"])["PrecursorMZ"].dropna(), dtype=float)[0,1])

slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(df_train.dropna(subset=["CCS"])["PRECURSORMZ"], df_train.dropna(subset=["CCS"])["CCS"])
print("R2")
print("GNN", r2_score(df_test_unique.dropna(subset=["CCS"])["CCS"], df_test_unique.dropna(subset=["CCS"])["CCS_pred"].dropna()))
print("LR ", r2_score(df_test_unique.dropna(subset=["CCS"])["CCS"], intercept + slope *df_test_unique.dropna(subset=["CCS"])["PrecursorMZ"].dropna()))

print("---------------\n\nCASMI-16:\n")
print("Pearson Corr Coef:")
print("GNN", np.corrcoef(casmi16_df.dropna(subset=["CCS"])["CCS"], casmi16_df.dropna(subset=["CCS"])["CCS_pred"].dropna(), dtype=float)[0,1])
print("LR ", np.corrcoef(casmi16_df.dropna(subset=["CCS"])["CCS"], casmi16_df.dropna(subset=["CCS"])["PRECURSOR_MZ"].dropna(), dtype=float)[0,1])
print("R2")
print("GNN", r2_score(casmi16_df.dropna(subset=["CCS"])["CCS"], casmi16_df.dropna(subset=["CCS"])["CCS_pred"].dropna()))
print("LR ", r2_score(casmi16_df.dropna(subset=["CCS"])["CCS"], intercept + slope *casmi16_df.dropna(subset=["CCS"])["PRECURSOR_MZ"].dropna()))
# Out:
# TEST SPLIT:
#
# Pearson Corr Coef:
# GNN 0.9519076313173315
# LR  0.9457218652952905
# R2
# GNN 0.9060538445205336
# LR  0.892610510091076
# ---------------
#
# CASMI-16:
#
# Pearson Corr Coef:
# GNN 0.9234824273124075
# LR  0.7941692301553979
# R2
# GNN 0.8517090126966476
# LR  0.6202341844806762
